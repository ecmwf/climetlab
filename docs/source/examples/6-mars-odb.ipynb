# %% [markdown]
# # ECMWF Observation bespoke format (ODB)

# %%
import climetlab as cml

# %%
source = cml.load_source("mars", 
                         type="ofb",
                         obsgroup="conv",
                         time="12",
                         format="odb",
                         reportype=16001,
                         date="2020-05-18")

# %%
pd = source.to_pandas()
# Out:
# Using pure Python odc decoder which is slow: [Errno 2] No such file or directory: '/usr/local/lib/python3.7/site-packages/processed_odc.h'

# %%
pd
# Out:
#       type    expver  class  stream    andate  antime  reportype  numtsl@desc  \
# 0      263      0001      1    1025  20200518  120000      16001           17
# 1      263      0001      1    1025  20200518  120000      16001           17
# 2      263      0001      1    1025  20200518  120000      16001           17
# 3      263      0001      1    1025  20200518  120000      16001           17
# 4      263      0001      1    1025  20200518  120000      16001           17
# ...    ...       ...    ...     ...       ...     ...        ...          ...
# 7855   263      0001      1    1025  20200518  120000      16001           17
# 7856   263      0001      1    1025  20200518  120000      16001           17
# 7857   263      0001      1    1025  20200518  120000      16001           17
# 7858   263      0001      1    1025  20200518  120000      16001           17
# 7859   263      0001      1    1025  20200518  120000      16001           17
#
# ...
