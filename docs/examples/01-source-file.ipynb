# %%
# !pip3 install --quiet climetlab

# %%
# !test -f test.grib || wget https://github.com/ecmwf/climetlab/raw/master/docs/examples/test.grib

# %%
# !test -f test.nc || wget https://github.com/ecmwf/climetlab/raw/master/docs/examples/test.nc

# %% [markdown]
# # Reading data from a file

# %%
import climetlab as  cml
# Out:
# WARNING: ecmwflibs universal: cannot find a library called eccodes
# WARNING: ecmwflibs universal: cannot find a library called MagPlus
# Magics library could not be found
# WARNING: ecmwflibs universal: cannot find a library called MagPlus
# Magics library could not be found

# %% [markdown]
# ### Plot GRIB data

# %%
source =  cml.load_source("file", "test.grib")
for s in source:
    cml.plot_map(s)
# Out:
# WARNING: ecmwflibs universal: cannot find a library called eccodes
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-2402cc942193> in <module>
#       1 source =  cml.load_source("file", "test.grib")
# ----> 2 for s in source:
#       3     cml.plot_map(s)
#
# ~/git/climetlab/climetlab/sources/base.py in __iter__(self)
#      35
#      36     def __iter__(self):
# ---> 37         return iter(self._reader)
#      38
#      39     def __len__(self):
#
# ~/git/climetlab/climetlab/sources/base.py in _reader(self)
#      31     def _reader(self):
#      32         if self._reader_ is None:
# ---> 33             self._reader_ = reader(self, self.path)
#      34         return self._reader_
#      35
#
# ~/git/climetlab/climetlab/sources/readers/__init__.py in reader(source, path)
#      97
#      98     if header in READERS:
# ...

# %% [markdown]
# ### Plot NetCDF data

# %%
source = cml.load_source("file", "test.nc")
for s in source:
    cml.plot_map(s)
# Out:
# Magics-warning: 'output_file' provided, ignoring 'output_format(s)'. Format set to 'png'
# Magics-warning: 'output_file' provided, ignoring 'output_format(s)'. Format set to 'png'
