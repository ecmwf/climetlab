# %%
# !pip install --quiet climetlab

# %%
# %config Application.log_level="INFO"

# %% [markdown]
# # More plotting examples

# %%
import climetlab as  cml

# %% [markdown]
# Get some GRIB data

# %%
ds =  cml.load_dataset("sample-grib-data")

# %% [markdown]
# Plot the first field

# %%
cml.plot_map(ds[0])
# Out:
# Error executing: [macro.output(
#    output_file='/var/folders/gt/_nyhyz497ns5szsvxw16gz6m0000gn/T/tmpwn3wzk2k.png',
#    output_width=680,
#    page_frame=False,
#    page_id_line=False,
#    page_x_length=10.0,
#    page_y_length=5.555555555555555,
#    subpage_x_length=10.0,
#    subpage_x_position=0.0,
#    subpage_y_length=5.555555555555555,
#    subpage_y_position=0.0,
#    super_page_x_length=10.0,
#    super_page_y_length=5.555555555555555,
#     ), macro.mmap(
#    subpage_lower_left_latitude=33.0,
#    subpage_lower_left_longitude=-27.0,
#    subpage_map_projection='cylindrical',
#    subpage_upper_right_latitude=73.0,
#    subpage_upper_right_longitude=45.0,
#     ), macro.mcoast(
#    map_boundaries=True,
#    map_coastline_colour='tan',
#    map_coastline_land_shade=True,
#    map_coastline_land_shade_colour='cream',
#    map_grid=False,
#    map_grid_colour='tan',
#    map_grid_frame=True,
#    map_grid_frame_thickness=5,
#    map_label=False,
#     ), macro.mgrib(
#    grib_field_position=0,
#    grib_file_address_mode='byte_offset',
#    grib_input_file_name='/var/folders/gt/_nyhyz497ns5szsvxw16gz6m0000gn/T/climetlab-baudouin/url-64c9f958e6e24d5ea7aa2cf8ebae7bcdf8d495ab7d7998d80032261313a26161.grib',
#     ), macro.mcont(
#    contour_automatic_setting='climetlab',
#    legend=False,
#     ), macro.mcoast(
#    map_grid=False,
#    map_grid_frame=True,
#    map_grid_frame_thickness=5,
#    map_label=False,
#     )]
# Traceback (most recent call last):
#   File "/Users/baudouin/git/climetlab/climetlab/plotting/drivers/magics/driver.py", line 365, in show
#     plot(*args)
#   File "/Users/baudouin/git/climetlab/climetlab/plotting/drivers/magics/actions.py", line 119, in plot
#     return macro.plot(*args, **kwargs)
#   File "/Users/baudouin/Library/Python/3.8/lib/python/site-packages/Magics/macro.py", line 879, in _jplot
#     _plot(all)
#   File "/Users/baudouin/Library/Python/3.8/lib/python/site-packages/Magics/macro.py", line 776, in _plot
#     Magics.finalize()
#   File "/Users/baudouin/Library/Python/3.8/lib/python/site-packages/Magics/Magics.py", line 188, in wrapped
#     raise MagicsError(char_to_string(err))
# Magics.Magics.MagicsError: Assertion failed: file_.substr(ext.size() - 1) == ext in getFileName, line 186 of /Users/runner/work/ecmwflibs/ecmwflibs/src/magics/src/drivers/BaseDriver.cc
# ---------------------------------------------------------------------------
# MagicsError                               Traceback (most recent call last)
# <ipython-input-5-2fdf4a47925c> in <module>
# ----> 1 cml.plot_map(ds[0])
#
# ~/git/climetlab/climetlab/plotting/__init__.py in plot_map(data, **kwargs)
#     106     p = new_plot(**kwargs)
#     107     p.plot_map(data)
# --> 108     p.show()
#     109
#     110
#
# ~/git/climetlab/climetlab/plotting/__init__.py in show(self)
#      81
#      82     def show(self):
# ---> 83         return display(self.driver.show())
#      84
#      85     def macro(self) -> list:
#
# ~/git/climetlab/climetlab/plotting/drivers/magics/driver.py in show(self)
#     363
#     364         try:
# --> 365             plot(*args)
#     366         except Exception:
#     367             LOG.error("Error executing: %r", args, exc_info=True)
#
# ~/git/climetlab/climetlab/plotting/drivers/magics/actions.py in plot(*args, **kwargs)
#     117
#     118 def plot(*args, **kwargs):
# --> 119     return macro.plot(*args, **kwargs)
#     120
#     121
#
# ~/Library/Python/3.8/lib/python/site-packages/Magics/macro.py in _jplot(*args)
#     877         all.extend(args)
#     878
# --> 879         _plot(all)
#     880
#     881         image = Image(tmp)
#
# ~/Library/Python/3.8/lib/python/site-packages/Magics/macro.py in _plot(*args)
#     774
#     775     # Collect the drivers!
# --> 776     Magics.finalize()
#     777     for f in context.tmp:
#     778         if os.path.exists(f):
#
# ~/Library/Python/3.8/lib/python/site-packages/Magics/Magics.py in wrapped(*args)
#     186         err = fn(*args)
#     187         if err:
# --> 188             raise MagicsError(char_to_string(err))
#     189
#     190     return wrapped
#
# MagicsError: Assertion failed: file_.substr(ext.size() - 1) == ext in getFileName, line 186 of /Users/runner/work/ecmwflibs/ecmwflibs/src/magics/src/drivers/BaseDriver.cc

# %% [markdown]
# Plot the second field

# %%
cml.plot_map(ds[1])

# %% [markdown]
# Plot both fields on the same map

# %%
cml.plot_map((ds[0], ds[1]))

# %% [markdown]
# Alternative method:

# %%
p = cml.new_plot()
p.plot_map(ds[0])
p.plot_map(ds[1])
p.show()

# %% [markdown]
# Switch off background map

# %%
cml.plot_map(ds[1], background=False)

# %% [markdown]
# Switch off both foreground and background

# %%
cml.plot_map(ds[1], foreground=False,)

# %% [markdown]
# ## Projections

# %%
from climetlab.plotting import projections

# %%
for projection in projections():
    cml.plot_map(projection=projection, title=projection)
# Out:
# Magics-warning: The parameter subpage_vertical_longitude was not found.
# Magics-warning: The parameter subpage_vertical_longitude was not found.

# %%
## Low-level graphical attributes

# %%
cml.plotting_options(width=500)

# %%
atlantic = cml.load_dataset("hurricane-database", "atlantic")

# %%
df = atlantic.to_pandas()

# %%
david = df[(df.name=='david')]

# %%
cml.plot_map(david, style=dict(symbol_colour="blue", 
                                    symbol_type="marker", 
                                    symbol_marker_index= 3))

# %%
cml.plot_map(david)

# %%
cml.plot_map(david,style={'+symbol_colour': 'blue'})

# %%
cml.plot_map(david, background={'map_coastline_land_shade': True,
                                'map_coastline_land_shade_colour': 'green'})

# %%
cml.plot_map(david, background=False)
