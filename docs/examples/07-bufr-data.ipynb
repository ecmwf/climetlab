# %%
# !pip install --quiet climetlab

# %% [markdown]
# # BUFR data

# %%
import climetlab as cml

# %%
source = cml.load_dataset("sample-bufr-data")

# %% [markdown]
# See https://github.com/ecmwf/pdbufr

# %%
pd = source.to_pandas(
    columns=('stationNumber', 'latitude', 'longitude', 'data_datetime', 'pressure', 'airTemperature'),
    filters={'pressure': 100000},
)

# %%
pd.head()
# Out:
#    pressure  airTemperature  stationNumber  latitude  longitude  \
# 0  100000.0    2.597000e+02            907     58.47     -78.08
# 1  100000.0  -1.000000e+100            823     53.75     -73.67
# 2  100000.0  -1.000000e+100              9    -90.00       0.00
# 3  100000.0    2.950000e+02            486     18.43     -69.88
# 4  100000.0    2.962000e+02            165     21.98    -159.33
#
#         data_datetime
# 0 2008-12-08 12:00:00
# 1 2008-12-08 12:00:00
# 2 2008-12-08 12:00:00
# 3 2008-12-08 12:00:00
# 4 2008-12-08 12:00:00

# %%
pd.tail()
# Out:
#      pressure  airTemperature  stationNumber  latitude  longitude  \
# 403  100000.0    2.942000e+02            650    -20.50     -29.32
# 404  100000.0    3.000000e+02             22      2.83     -60.70
# 405  100000.0    2.966000e+02            411     -3.67     -69.67
# 406  100000.0  -1.000000e+100            612    -20.47     -54.67
# 407  100000.0    2.896000e+02            968     25.03     121.52
#
#           data_datetime
# 403 2008-12-08 12:00:00
# 404 2008-12-08 12:00:00
# 405 2008-12-08 12:00:00
# 406 2008-12-08 12:00:00
# 407 2008-12-08 12:00:00

# %%
cml.plot_map(pd, projection='global')
