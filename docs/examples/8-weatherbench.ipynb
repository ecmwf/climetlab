# %%
# !pip install --quiet climetlab matplotlib

# %% [markdown]
# # WeatherBench

# %% [markdown]
# This is an attempt to reproduce this research: https://arxiv.org/abs/2002.00469. There is a notebook available at: https://binder.pangeo.io/v2/gh/pangeo-data/WeatherBench/master?filepath=quickstart.ipynb

# %%
import matplotlib.pyplot as plt

# %%
import climetlab as cml

# %%
ds = cml.load_dataset("weather-bench")
# Out:
# Downloading https://dataserv.ub.tum.de/s/m1524895/download?path=%2F5.625deg%2Fgeopotential_500&files=geopotential_500_5.625deg.zip
#   0%|          | 0/40 [00:00<?, ?it/s]
# Unzipping...
# Done...

# %%
z500 = ds.to_xarray()

# %%
z500
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 32, lon: 64, time: 350640)
# Coordinates:
#     level    int32 500
#   * lat      (lat) float64 -87.19 -81.56 -75.94 -70.31 ... 75.94 81.56 87.19
#   * lon      (lon) float64 0.0 5.625 11.25 16.88 ... 337.5 343.1 348.8 354.4
#   * time     (time) datetime64[ns] 1979-01-01 ... 2018-12-31T23:00:00
# Data variables:
#     z        (time, lat, lon) float32 dask.array<chunksize=(8760, 32, 64), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2019-11-10 20:33:23 GMT by grib_to_netcdf-2.14.0: /opt/ecmw...

# %%
cml.plot_map(z500)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-be43958bb1c6> in <module>
# ----> 1 cml.plot_map(z500)
#
# /usr/local/lib/python3.8/site-packages/climetlab/plotting/__init__.py in plot_map(data, *args, **kwargs)
#      48             raise ValueError("Cannot plot %s" % (fullname,))
#      49
# ---> 50     data.plot_map(CURRENT_DRIVER)
#      51
#      52     return display(CURRENT_DRIVER.show(**kwargs))
#
# /usr/local/lib/python3.8/site-packages/climetlab/plotting/helpers/xarray.py in plot_map(self, driver)
#      43             dimension_settings[d] = self.data[d].data[0]
#      44
# ---> 45         driver.plot_xarray(self.data, self.name, dimension_settings)
#      46
#      47
#
# /usr/local/lib/python3.8/site-packages/climetlab/plotting/drivers/magics.py in plot_xarray(self, ds, variable, dimension_settings)
#      82
#      83     def plot_xarray(self, ds, variable, dimension_settings={}):
# ---> 84         self._data = macro.mxarray(xarray_dataset=ds,
#      85                                    xarray_variable_name=variable,
#      86                                    xarray_dimension_settings=dimension_settings)
#
# /usr/local/lib/python3.8/site-packages/Magics/macro.py in mxarray(xarray_dataset, xarray_variable_name, xarray_dimension_settings)
#     544     # lat/lon data in xarray_dataset.data_vars instead.
#     545     for ds_attributes in [xarray_dataset.coords, xarray_dataset.data_vars]:
# --> 546         ret = _mxarray(
#     547             xarray_dataset,
#     548             xarray_variable_name,
#
# /usr/local/lib/python3.8/site-packages/Magics/macro.py in _mxarray(xarray_dataset, xarray_variable_name, ds_attributes, xarray_dimension_settings)
#     573             )
#     574         elif n_lat_dims == 1:
# --> 575             return _mxarray_1d(
#     576                 xarray_dataset,
#     577                 xarray_variable_name,
#
# /usr/local/lib/python3.8/site-packages/Magics/macro.py in _mxarray_1d(xarray_dataset, xarray_variable_name, lat_name, lon_name, xarray_dimension_settings)
#     601     lat = xarray_dataset[lat_name].values.astype(numpy.float64)
#     602     lon = xarray_dataset[lon_name].values.astype(numpy.float64)
# --> 603     input_field_values = _mxarray_flatten(
#     604         xarray_dataset[xarray_variable_name],
#     605         xarray_dimension_settings,
#
# /usr/local/lib/python3.8/site-packages/Magics/macro.py in _mxarray_flatten(xarray_dataset, dims_to_flatten, dims_to_ignore)
#     657                 )
#     658             else:
# --> 659                 xarray_dataset = xarray_dataset.loc[{dim: dims_to_flatten[dim]}]
#     660         elif xarray_dataset[dim].size == 1:
#     661             # automatically squash this dimension
#
# /usr/local/lib/python3.8/site-packages/xarray/core/dataarray.py in __getitem__(self, key)
#     196             labels = indexing.expanded_indexer(key, self.data_array.ndim)
#     197             key = dict(zip(self.data_array.dims, labels))
# --> 198         return self.data_array.sel(**key)
#     199
#     200     def __setitem__(self, key, value) -> None:
#
# /usr/local/lib/python3.8/site-packages/xarray/core/dataarray.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1147
#    1148         """
# -> 1149         ds = self._to_temp_dataset().sel(
#    1150             indexers=indexers,
#    1151             drop=drop,
#
# /usr/local/lib/python3.8/site-packages/xarray/core/dataset.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2099         """
#    2100         indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2101         pos_indexers, new_indexes = remap_label_indexers(
#    2102             self, indexers=indexers, method=method, tolerance=tolerance
#    2103         )
#
# /usr/local/lib/python3.8/site-packages/xarray/core/coordinates.py in remap_label_indexers(obj, indexers, method, tolerance, **indexers_kwargs)
#     394     }
#     395
# --> 396     pos_indexers, new_indexes = indexing.remap_label_indexers(
#     397         obj, v_indexers, method=method, tolerance=tolerance
#     398     )
#
# /usr/local/lib/python3.8/site-packages/xarray/core/indexing.py in remap_label_indexers(data_obj, indexers, method, tolerance)
#     268             coords_dtype = data_obj.coords[dim].dtype
#     269             label = maybe_cast_to_coords_dtype(label, coords_dtype)
# --> 270             idxr, new_idx = convert_label_indexer(index, label, dim, method, tolerance)
#     271             pos_indexers[dim] = idxr
#     272             if new_idx is not None:
#
# /usr/local/lib/python3.8/site-packages/xarray/core/indexing.py in convert_label_indexer(index, label, index_name, method, tolerance)
#     187                 indexer = index.get_loc(label.item())
#     188             else:
# --> 189                 indexer = index.get_loc(
#     190                     label.item(), method=method, tolerance=tolerance
#     191                 )
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py in get_loc(self, key, method, tolerance)
#     620         else:
#     621             # unrecognized type
# --> 622             raise KeyError(key)
#     623
#     624         try:
#
# KeyError: 283996800000000000

# %%
z500.z.isel(time=0).plot()

# %%
cml.plot_map(z500.z.isel(time=0))

# %%
climatology = z500.sel(time=slice('2016', '2016')).mean('time').load()

# %%
climatology.z.plot()

# %%
cml.plot_map(climatology.z)

# %%
climatology.z
