# %%
# !pip install --quiet climetlab

# %%
import climetlab as cml

# %%
r = {"class": "e2",
    "date": "1662-10-01/to/1663-12-31",
    "dataset": "icoads",
    "expver": "1608",
    "groupid": "17",
    "reportype": "16008",
    "format": "ascii",
    "stream": "oper",
    "time": "all",
    "type": "ofb"}


source = cml.load_source("mars", **r)
# Out:
# 2021-01-18 09:57:51 ECMWF API python library 1.6.1
# 2021-01-18 09:57:51 ECMWF API at https://api.ecmwf.int/v1
# 2021-01-18 09:57:51 Welcome Baudouin Raoult
# 2021-01-18 09:57:51 In case of problems, please check https://confluence.ecmwf.int/display/WEBAPI/Web+API+FAQ or contact servicedesk@ecmwf.int
# 2021-01-18 09:57:52 Request submitted
# 2021-01-18 09:57:52 Request id: 60055ba0e3c377ad9fc5f29c
# 2021-01-18 09:57:52 Request is submitted
# 2021-01-18 09:57:53 Request is active
#     STREAM     = OPER,
#     EXPVER     = 1608,
#     REPRES     = BU,
#     REPORTYPE  = 16008,
#     OBSTYPE    = 1,
#     TIME       = ALL,
#     DOMAIN     = G,
#     PADDING    = 0,
#     DUPLICATES = KEEP,
#     DATE       = 
#
# mars - INFO   - 20210118.095941 - Calling mars on 'marser', local port is 48773
# mars - INFO   - 20210118.095943 - Server task is 744 [marser]
# mars - INFO   - 20210118.095943 - Request cost: 0 field,  [marser]
# mars - WARN   - 20210118.095943 - Data not found [marser]
# mars - INFO   - 20210118.095943 - odb_filter: sql = 'NULL', total_to_read = 0
# mars - INFO   - 20210118.095943 - Request time:  wall: 2 sec
# mars - INFO   - 20210118.095943 -   Processing in marser: wall: 2 sec
# mars - INFO   - 20210118.095943 -   Visiting marser: wall: 2 sec
#
# mars - INFO   - 20210118.095943 - Processing request 13
#
# RETRIEVE,
#     DATASET    = icoads,
#     CLASS      = E2,
#     TYPE       = OFB,
#     STREAM     = OPER,
#     EXPVER     = 1608,
#     REPRES     = BU,
#     REPORTYPE  = 16008,
#     OBSTYPE    = 1,
#     TIME       = ALL,
#     DOMAIN     = G,
#     PADDING    = 0,
#     DUPLICATES = KEEP,
#     DATE       = 
#
# mars - INFO   - 20210118.095943 - Calling mars on 'marser', local port is 54124
# mars - INFO   - 20210118.095944 - Server task is 744 [marser]
# mars - INFO   - 20210118.095944 - Request cost: 0 field,  [marser]
# mars - WARN   - 20210118.095944 - Data not found [marser]
# mars - INFO   - 20210118.095944 - odb_filter: sql = 'NULL', total_to_read = 0
#
# mars - INFO   - 20210118.095944 - Processing request 14
#
# RETRIEVE,
#     DATASET    = icoads,
#     CLASS      = E2,
#     TYPE       = OFB,
#     STREAM     = OPER,
#     EXPVER     = 1608,
#     REPRES     = BU,
#     REPORTYPE  = 16008,
#     OBSTYPE    = 1,
#     TIME       = ALL,
#     DOMAIN     = G,
#     PADDING    = 0,
#     DUPLICATES = KEEP,
#     DATE       = 
#
# mars - INFO   - 20210118.095944 - Calling mars on 'marser', local port is 58753
# mars - INFO   - 20210118.095946 - Server task is 179 [marser]
# mars - INFO   - 20210118.095946 - Request cost: 0 field,  [marser]
# mars - WARN   - 20210118.095946 - Data not found [marser]
# mars - INFO   - 20210118.095946 - odb_filter: sql = 'NULL', total_to_read = 0
# mars - INFO   - 20210118.095946 - Request time:  wall: 2 sec
# mars - INFO   - 20210118.095946 -   Processing in marser: wall: 2 sec
# mars - INFO   - 20210118.095946 -   Visiting marser: wall: 2 sec
#
# mars - INFO   - 20210118.095946 - Processing request 15
#
# RETRIEVE,
#     DATASET    = icoads,
#     CLASS      = E2,
#     TYPE       = OFB,
#     STREAM     = OPER,
#     EXPVER     = 1608,
#     REPRES     = BU,
#     REPORTYPE  = 16008,
#     OBSTYPE    = 1,
#     TIME       = ALL,
#     DOMAIN     = G,
#     PADDING    = 0,
#     DUPLICATES = KEEP,
#     DATE       = 
#
# mars - INFO   - 20210118.095946 - Calling mars on 'marser', local port is 51330
# mars - INFO   - 20210118.095946 - Server task is 812 [marser]
# mars - INFO   - 20210118.095946 - Request cost: 0 field,  [marser]
# mars - WARN   - 20210118.095946 - Data not found [marser]
# mars - INFO   - 20210118.095946 - odb_filter: sql = 'NULL', total_to_read = 0
# mars - INFO   - 20210118.095946 - Request time:  wall: 1 sec
# mars - INFO   - 20210118.095946 - Memory used: 45.61 Mbyte(s)
# mars - INFO   - 20210118.095946 - No errors reported
# Process '['nice', 'mars', '/tmp/20210118-0950/5b/tmp-_marsJZZuHs.req']' finished
# Calling 'nice odb sql select * -i /data/scratch/20210118-0950/09/_mars-webmars-private-svc-blue-005-6fe5cac1a363ec1525f54343b6cc9fd8-S9Urh8.odb -o /data/scratch/20210118-0950/1a/odb_filter-webmars-private-svc-blue-006-6fe5cac1a363ec1525f54343b6cc9fd8-R4YPRB.txt -f default'
# 000 2021-01-18 09:59:47 (I) Matching row(s): 678 out of 678
# 000 2021-01-18 09:59:47 (I) Skips: 0
# 000 2021-01-18 09:59:47 (I) Execute: 0.026455 second elapsed, 0.02 second cpu
# Process '['nice', 'odb', 'sql', 'select *', '-i', '/data/scratch/20210118-0950/09/_mars-webmars-private-svc-blue-005-6fe5cac1a363ec1525f54343b6cc9fd8-S9Urh8.odb', '-o', '/data/scratch/20210118-0950/1a/odb_filter-webmars-private-svc-blue-006-6fe5cac1a363ec1525f54343b6cc9fd8-R4YPRB.txt', '-f', 'default']' finished
# 2021-01-18 09:59:58 Request is complete
# 2021-01-18 09:59:58 Transfering 13.0352 Kbytes into /var/folders/gt/_nyhyz497ns5szsvxw16gz6m0000gn/T/climetlab-baudouin/marsretriever-a1a7fcd5ea53a1bdd112f3836543587c6012a82142452dd114131503a40aee77.cache.tmp
# 2021-01-18 09:59:58 From https://stream.ecmwf.int/data/webmars-private-svc-blue-009/data/scratch/20210118-0950/3e/zipcompress-webmars-private-svc-blue-009-6fe5cac1a363ec1525f54343b6cc9fd8-GxixGM.zip
# 2021-01-18 09:59:58 Transfer rate 150.443 Kbytes/s
# 2021-01-18 09:59:58 Done.

# %%
pd = source.to_pandas()

# %%
pd
# Out:
#      expver@desc  type@desc  class@desc  stream@desc  andate@desc  \
# 0    '1608'             263          22         1025     16621015
# 1    '1608'             263          22         1025     16621015
# 2    '1608'             263          22         1025     16621015
# 3    '1608'             263          22         1025     16621015
# 4    '1608'             263          22         1025     16621016
# ..           ...        ...         ...          ...          ...
# 673  '1608'             263          22         1025     16630425
# 674  '1608'             263          22         1025     16630426
# 675  '1608'             263          22         1025     16630426
# 676  '1608'             263          22         1025     16630426
# 677  '1608'             263          22         1025     16630426
#
#      antime@desc  seqno@hdr  reportype@hdr  bufrtype@hdr  subtype@hdr  ...  \
# 0         120000          1          16008             1           11  ...
# 1         120000          1          16008             1           11  ...
# 2         120000          1          16008             1           11  ...
# 3         120000          1          16008             1           11  ...
# 4         120000          2          16008             1           11  ...
# ..           ...        ...            ...           ...          ...  ...
# 673        60000         25          16008             1           11  ...
# 674        60000         26          16008             1           11  ...
# 675        60000         26          16008             1           11  ...
# 676        60000         26          16008             1           11  ...
# 677        60000         26          16008             1           11  ...
#
#      entryno@body  obsvalue@body  varno@body  vertco_type@body  \
# 0               1     158.000000         111                 1
# 1               2       2.600000         112                 1
# 2               3      -0.973977          41                 1
# 3               4       2.410678          42                 1
# 4               1     158.000000         111                 1
# ..            ...            ...         ...               ...
# 673             4       2.155498          42                 1
# 674             1     124.000000         111                 1
# 675             2       6.700000         112                 1
# 676             3      -5.554552          41                 1
# 677             4       3.746593          42                 1
#
#     vertco_reference_1@body  datum_status@body  bias_volatility@body  \
# 0                       0.0                  1                   NaN
# 1                       0.0                  1                   NaN
# 2                       0.0                  1                   NaN
# 3                       0.0                  1                   NaN
# 4                       0.0                  1                   NaN
# ..                      ...                ...                   ...
# 673                     0.0                  1                   NaN
# 674                     0.0                  1                   NaN
# 675                     0.0                  1                   NaN
# 676                     0.0                  1                   NaN
# 677                     0.0                  1                   NaN
#
#      an_depar@body  fg_depar@body  ppcode@conv_body
# 0              NaN            NaN                 0
# 1              NaN            NaN                 0
# 2              NaN            NaN                 0
# 3              NaN            NaN                 0
# 4              NaN            NaN                 0
# ..             ...            ...               ...
# 673            NaN            NaN                 0
# 674            NaN            NaN                 0
# 675            NaN            NaN                 0
# 676            NaN            NaN                 0
# 677            NaN            NaN                 0
#
# [678 rows x 44 columns]

# %%
cml.plot_map(pd, margins=2)
