# %%
# !pip install --quiet climetlab

# %% [markdown]
# # ECMWF Observation bespoke format (ODB)

# %%
import climetlab as cml

# %%
source = cml.load_source("mars", 
                         type="ofb",
                         obsgroup="conv",
                         time="12",
                         format="odb",
                         reportype=16001,
                         date="2020-05-18")
# Out:
# 2020-09-01 10:58:27 ECMWF API python library 1.5.4
# 2020-09-01 10:58:27 ECMWF API at https://api.ecmwf.int/v1
# 2020-09-01 10:58:29 Welcome Baudouin Raoult
# 2020-09-01 10:58:29 In case of problems, please check https://confluence.ecmwf.int/display/WEBAPI/Web+API+FAQ or contact servicedesk@ecmwf.int
# 2020-09-01 10:58:30 Request submitted
# 2020-09-01 10:58:30 Request id: 5f4e1b4638fb1d2c9df0cf92
# 2020-09-01 10:58:30 Request is submitted
# 2020-09-01 10:58:31 Request is active
# Calling 'nice mars /tmp/20200901-0950/c3/tmp-_marsJNJki7.req'
# mars - WARN -
# mars - WARN - From 29 January 2019 10AM (UTC) MARS uses the interpolation
# mars - WARN - provided by the MIR library. For more details, see
# mars - WARN - https://confluence.ecmwf.int/display/UDOC/MARS+interpolation+with+MIR
# mars - WARN -
# MIR environment variables:
# MIR_CACHE_PATH=/data/ec_coeff
# mars - INFO   - 20200901.095831 - Welcome to MARS
# mars - INFO   - 20200901.095831 - MARS Client bundle version: 6.28.6.1
# mars - INFO   - 20200901.095831 - MARS Client package version: 6.28.6
# mars - INFO   - 20200901.095831 - MARS Client build stamp: 20200717102127
# mars - INFO   - 20200901.095831 - MIR version: 1.4.7
# mars - INFO   - 20200901.095831 - Using ecCodes version 2.18.0
# mars - INFO   - 20200901.095831 - Using odb_api version: 0.15.11 (file format version: 0.5)
# mars - INFO   - 20200901.095831 - Using FDB5 version: 5.6.1
# mars - INFO   - 20200901.095831 - Maximum retrieval size is 50.00 G
# retrieve,obsgroup=conv,reportype=16001,padding=0,time=12,date=2020-05-18,type=ofbmars - INFO   - 20200901.095831 - Automatic split by date is on
#
# mars - INFO   - 20200901.095831 - Processing request 1
#
# RETRIEVE,
#     CLASS      = OD,
#     TYPE       = OFB,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = BU,
#     OBSGROUP   = CONV,
#     REPORTYPE  = 16001,
#     OBSTYPE    = 1,
#     TIME       = 1200,
#     DOMAIN     = G,
#     PADDING    = 0,
#     DUPLICATES = KEEP,
#     DATE       = 20200518
#
# mars - INFO   - 20200901.095831 - Web API request id: 5f4e1b4638fb1d2c9df0cf92
# mars - INFO   - 20200901.095831 - Calling mars on 'marsod', local port is 54645
# mars - INFO   - 20200901.095833 - Server task is 403 [marsod]
# mars - INFO   - 20200901.095833 - Request cost: 1 field, 25.5883 Mbytes online, nodes: mvr09 [marsod]
# mars - INFO   - 20200901.095833 - Transfering 26831236 bytes
# mars - INFO   - 20200901.095833 - odb_filter: sql = 'NULL', total_to_read = 26831236
# mars - INFO   - 20200901.095834 - Read  rate: 230.768 Mbytes per second
# mars - INFO   - 20200901.095834 - Write rate: 1.31935 Gbytes per second
# mars - INFO   - 20200901.095834 - Save into: 0.130028 second elapsed, 0.07 second cpu
# mars - INFO   - 20200901.095834 -  => odb_filter
# mars - INFO   - 20200901.095834 - Request time:  wall: 3 sec
# mars - INFO   - 20200901.095834 -   Processing in marsod: wall: 3 sec
# mars - INFO   - 20200901.095834 -   Visiting marsod: wall: 3 sec
# mars - INFO   - 20200901.095834 - Memory used: 46.99 Mbyte(s)
# mars - INFO   - 20200901.095834 - No errors reported
# Process '['nice', 'mars', '/tmp/20200901-0950/c3/tmp-_marsJNJki7.req']' finished
# 2020-09-01 10:58:36 Request is complete
# 2020-09-01 10:58:36 Transfering 25.5883 Mbytes into /var/tmp/climetlab-baudouin/marsretriever-fb77430fc93206e50b2e01df883a59fa5e8c362534f6fc952ac146e84e030f84.cache.tmp
# 2020-09-01 10:58:36 From https://stream.ecmwf.int/data/webmars-private-svc-blue-011/data/scratch/20200901-0950/45/_mars-webmars-private-svc-blue-011-6fe5cac1a363ec1525f54343b6cc9fd8-bbPrmK.odb
# 2020-09-01 10:59:08 Transfer rate 824.717 Kbytes/s
# 2020-09-01 10:59:08 Done.

# %%
pd = source.to_pandas()
# Out:
# Using pure Python odc decoder.

# %%
pd
# Out:
#         type    expver  class  stream    andate  antime  reportype  \
# 0        263      0001      1    1025  20200518  120000      16001
# 1        263      0001      1    1025  20200518  120000      16001
# 2        263      0001      1    1025  20200518  120000      16001
# 3        263      0001      1    1025  20200518  120000      16001
# 4        263      0001      1    1025  20200518  120000      16001
# ...      ...       ...    ...     ...       ...     ...        ...
# 410015   263      0001      1    1025  20200518  120000      16001
# 410016   263      0001      1    1025  20200518  120000      16001
# 410017   263      0001      1    1025  20200518  120000      16001
# 410018   263      0001      1    1025  20200518  120000      16001
# 410019   263      0001      1    1025  20200518  120000      16001
#
#         numtsl@desc  timeslot@timeslot_index  seqno@hdr  ...  \
# 0                17                       15       4443  ...
# 1                17                       15       4443  ...
# 2                17                       15       4443  ...
# 3                17                       15       4443  ...
# 4                17                       15       4443  ...
# ...             ...                      ...        ...  ...
# 410015           17                       15    9133718  ...
# 410016           17                       15    9133718  ...
# 410017           17                       15    9133718  ...
# 410018           17                       15    9133718  ...
# 410019           17                       15    9133718  ...
#
#         datum_rdbflag@body  biascorr@body  biascorr_fg@body  qc_pge@body  \
# 0                        0            NaN               NaN          NaN
# 1                        0            NaN               NaN          NaN
# 2                        0            0.0               0.0          NaN
# 3                        0            0.0               0.0          NaN
# 4                        0            0.0               0.0          NaN
# ...                    ...            ...               ...          ...
# 410015                   0            0.0               0.0          NaN
# 410016                   0            0.0               0.0          NaN
# 410017                   0            0.0               0.0          NaN
# 410018                   0            0.0               0.0          NaN
# 410019                   0            0.0               0.0          NaN
#
#         an_depar@body  fg_depar@body obs_error@errstat  \
# 0          -10.560810     -14.283884         41.155659
# 1           36.250599      34.712360         41.155659
# 2           -9.160848     -12.384340         33.596455
# 3                 NaN            NaN               NaN
# 4            2.482570       2.683633          1.408449
# ...               ...            ...               ...
# 410015            NaN            NaN               NaN
# 410016            NaN            NaN               NaN
# 410017            NaN            NaN               NaN
# 410018            NaN            NaN               NaN
# 410019            NaN            NaN               NaN
#
#        final_obs_error@errstat  fg_error@errstat  eda_spread@errstat
# 0                    41.155659         25.144444           13.044278
# 1                    41.155659         25.144444           13.044278
# 2                    33.596455          0.260278            0.011694
# 3                          NaN               NaN                 NaN
# 4                     1.408449          0.502528            0.395115
# ...                        ...               ...                 ...
# 410015                     NaN               NaN                 NaN
# 410016                     NaN               NaN                 NaN
# 410017                     NaN               NaN                 NaN
# 410018                     NaN               NaN                 NaN
# 410019                     NaN               NaN                 NaN
#
# [410020 rows x 51 columns]

# %%
cml.plot_map(pd)
