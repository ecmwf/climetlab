# %%
# !pip install --quiet climetlab

# %% [markdown]
# # NOAA's hurricane database

# %%
import climetlab as  cml

# %%
hurdat2 = cml.load_dataset("hurricane-database")

# %%
hurdat2.home_page
# Out:
# 'https://www.aoml.noaa.gov/hrd/hurdat/Data_Storm.html'

# %% [markdown]
# Get the Pandas frame

# %%
df = hurdat2.to_pandas()

# %% [markdown]
# ## Huricanes making landfall at category 5

# %%
df[(df.category==5) & (df.type=='L')]
# Out:
#              id bassin  number  year     name                time type status  \
# 17942  AL031935     AL       3  1935  unnamed 1935-09-03 02:00:00    L     HU
# 24300  AL101955     AL      10  1955    janet 1955-09-27 17:00:00    L     HU
# 24303  AL101955     AL      10  1955    janet 1955-09-28 05:00:00    L     HU
# 28888  AL091969     AL       9  1969  camille 1969-08-18 04:00:00    L     HU
# 36448  AL081988     AL       8  1988  gilbert 1988-09-14 15:00:00    L     HU
# 37967  AL041992     AL       4  1992   andrew 1992-08-23 21:00:00    L     HU
# 37971  AL041992     AL       4  1992   andrew 1992-08-24 08:40:00    L     HU
# 37972  AL041992     AL       4  1992   andrew 1992-08-24 09:05:00    L     HU
# 45134  AL042007     AL       4  2007     dean 2007-08-21 08:30:00    L     HU
# 45182  AL062007     AL       6  2007    felix 2007-09-04 12:00:00    L     HU
# 49925  AL112017     AL      11  2017     irma 2017-09-06 05:45:00    L     HU
# 49927  AL112017     AL      11  2017     irma 2017-09-06 11:15:00    L     HU
# 49929  AL112017     AL      11  2017     irma 2017-09-06 16:30:00    L     HU
# 49941  AL112017     AL      11  2017     irma 2017-09-09 03:00:00    L     HU
# 50139  AL152017     AL      15  2017    maria 2017-09-19 01:15:00    L     HU
# 50835  AL142018     AL      14  2018  michael 2018-10-10 17:30:00    L     HU
#
#         lat   lon  knots  category  pressure
# 17942  24.8 -80.8  160.0         5     892.0
# 24300  17.4 -83.9  140.0         5       NaN
# 24303  18.4 -87.8  150.0         5     914.0
# 28888  30.3 -89.4  150.0         5     900.0
# 36448  20.7 -87.0  140.0         5     900.0
# 37967  25.4 -76.6  140.0         5     923.0
# 37971  25.5 -80.2  145.0         5     926.0
# 37972  25.5 -80.3  145.0         5     922.0
# 45134  18.7 -87.7  150.0         5     905.0
# 45182  14.3 -83.2  140.0         5     934.0
# 49925  17.7 -61.8  155.0         5     914.0
# 49927  18.1 -63.1  155.0         5     914.0
# 49929  18.5 -64.4  155.0         5     915.0
# 49941  22.3 -77.9  145.0         5     924.0
# 50139  15.4 -61.3  145.0         5     922.0
# 50835  30.0 -85.5  140.0         5     919.0

# %% [markdown]
# ## Get the track for Katrina

# %%
katrina = df[(df.name=='katrina') & (df.year==2005)]

# %%
katrina
# Out:
#              id bassin  number  year     name                time type status  \
# 44065  AL122005     AL      12  2005  katrina 2005-08-23 18:00:00          TD
# 44066  AL122005     AL      12  2005  katrina 2005-08-24 00:00:00          TD
# 44067  AL122005     AL      12  2005  katrina 2005-08-24 06:00:00          TD
# 44068  AL122005     AL      12  2005  katrina 2005-08-24 12:00:00          TS
# 44069  AL122005     AL      12  2005  katrina 2005-08-24 18:00:00          TS
# 44070  AL122005     AL      12  2005  katrina 2005-08-25 00:00:00          TS
# 44071  AL122005     AL      12  2005  katrina 2005-08-25 06:00:00          TS
# 44072  AL122005     AL      12  2005  katrina 2005-08-25 12:00:00          TS
# 44073  AL122005     AL      12  2005  katrina 2005-08-25 18:00:00          TS
# 44074  AL122005     AL      12  2005  katrina 2005-08-25 22:30:00    L     HU
# 44075  AL122005     AL      12  2005  katrina 2005-08-26 00:00:00          HU
# 44076  AL122005     AL      12  2005  katrina 2005-08-26 06:00:00          HU
# 44077  AL122005     AL      12  2005  katrina 2005-08-26 12:00:00          HU
# 44078  AL122005     AL      12  2005  katrina 2005-08-26 18:00:00          HU
# 44079  AL122005     AL      12  2005  katrina 2005-08-27 00:00:00          HU
# 44080  AL122005     AL      12  2005  katrina 2005-08-27 06:00:00          HU
# 44081  AL122005     AL      12  2005  katrina 2005-08-27 12:00:00          HU
# 44082  AL122005     AL      12  2005  katrina 2005-08-27 18:00:00          HU
# 44083  AL122005     AL      12  2005  katrina 2005-08-28 00:00:00          HU
# 44084  AL122005     AL      12  2005  katrina 2005-08-28 06:00:00          HU
# 44085  AL122005     AL      12  2005  katrina 2005-08-28 12:00:00          HU
# 44086  AL122005     AL      12  2005  katrina 2005-08-28 18:00:00          HU
# 44087  AL122005     AL      12  2005  katrina 2005-08-29 00:00:00          HU
# 44088  AL122005     AL      12  2005  katrina 2005-08-29 06:00:00          HU
# 44089  AL122005     AL      12  2005  katrina 2005-08-29 11:10:00    L     HU
# 44090  AL122005     AL      12  2005  katrina 2005-08-29 12:00:00          HU
# 44091  AL122005     AL      12  2005  katrina 2005-08-29 14:45:00    L     HU
# 44092  AL122005     AL      12  2005  katrina 2005-08-29 18:00:00          HU
# 44093  AL122005     AL      12  2005  katrina 2005-08-30 00:00:00          TS
# 44094  AL122005     AL      12  2005  katrina 2005-08-30 06:00:00          TS
# 44095  AL122005     AL      12  2005  katrina 2005-08-30 12:00:00          TD
# 44096  AL122005     AL      12  2005  katrina 2005-08-30 18:00:00          TD
# 44097  AL122005     AL      12  2005  katrina 2005-08-31 00:00:00          EX
# 44098  AL122005     AL      12  2005  katrina 2005-08-31 06:00:00          EX
#
#         lat   lon  knots  category  pressure
# 44065  23.1 -75.1   30.0         1    1008.0
# 44066  23.4 -75.7   30.0         1    1007.0
# 44067  23.8 -76.2   30.0         1    1007.0
# 44068  24.5 -76.5   35.0         1    1006.0
# 44069  25.4 -76.9   40.0         1    1003.0
# 44070  26.0 -77.7   45.0         1    1000.0
# 44071  26.1 -78.4   50.0         1     997.0
# 44072  26.2 -79.0   55.0         1     994.0
# 44073  26.2 -79.6   60.0         1     988.0
# 44074  26.0 -80.1   70.0         1     984.0
# 44075  25.9 -80.3   70.0         1     983.0
# 44076  25.4 -81.3   65.0         1     987.0
# 44077  25.1 -82.0   75.0         1     979.0
# 44078  24.9 -82.6   85.0         2     968.0
# 44079  24.6 -83.3   90.0         2     959.0
# 44080  24.4 -84.0   95.0         2     950.0
# 44081  24.4 -84.7  100.0         3     942.0
# 44082  24.5 -85.3  100.0         3     948.0
# 44083  24.8 -85.9  100.0         3     941.0
# 44084  25.2 -86.7  125.0         4     930.0
# 44085  25.7 -87.7  145.0         5     909.0
# 44086  26.3 -88.6  150.0         5     902.0
# 44087  27.2 -89.2  140.0         5     905.0
# 44088  28.2 -89.6  125.0         4     913.0
# 44089  29.3 -89.6  110.0         3     920.0
# 44090  29.5 -89.6  110.0         3     923.0
# 44091  30.2 -89.6  105.0         3     928.0
# 44092  31.1 -89.6   80.0         1     948.0
# 44093  32.6 -89.1   50.0         1     961.0
# 44094  34.1 -88.6   40.0         1     978.0
# 44095  35.6 -88.0   30.0         1     985.0
# 44096  37.0 -87.0   30.0         1     990.0
# 44097  38.6 -85.3   30.0         1     994.0
# 44098  40.1 -82.9   25.0         1     996.0

# %% [markdown]
# ## Plot the track

# %%
cml.plot_map(katrina, style='cyclone-track', margins=1.5)

# %% [markdown]
# ## Retrieve matching fields from ERA5

# %%
source = cml.load_source("cds", 
                         "reanalysis-era5-single-levels",
                         variable="msl",
                         product_type= "reanalysis",
                         based_on={"data": katrina, "extent": "bounding-box", "margins": 1.5})

for s in source:
    cml.plot_map(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-137a3bf0c136> in <module>
#       3                          variable="msl",
#       4                          product_type= "reanalysis",
# ----> 5                          based_on={"data": katrina, extent: "bounding-box", margins: 1.5})
#       6
#       7 for s in source:
#
# NameError: name 'extent' is not defined
