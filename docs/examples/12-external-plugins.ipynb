# %%
# !pip install --quiet climetlab climetlab-demo-source climetlab-demo-dataset

# %% [markdown]
# # External plugins

# %%
import climetlab as  cml

# %% [markdown]
# Get the demo dataset:

# %%
ds =  cml.load_dataset("demo-dataset")

# %% [markdown]
# Plot it:

# %%
cml.plot_map(ds)

# %% [markdown]
# ## External data source

# %%
# !test -f test.db || wget https://github.com/ecmwf/climetlab/raw/main/docs/examples/test.db

# %%
s = cml.load_source("demo-source", 
                    "sqlite:///test.db", 
                    "select * from data;", 
                    parse_dates=["time"])

# %%
df = s.to_pandas()

# %%
df
# Out:
#     lat  lon       time  value
# 0  50.0  3.3 2001-01-01    4.9
# 1  51.0 -3.0 2001-01-02    7.3
# 2  50.5 -1.8 2001-01-03    5.5

# %%
cml.plot_map(df, margins=2)
