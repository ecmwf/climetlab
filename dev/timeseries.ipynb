# %%
import climetlab as cml

# %%
s = cml.load_source("file", "timeseries.csv")

# %%
s.to_pandas()
# Out:
#          date  value
# 0  2000-01-01     43
# 1  2000-01-02     56
# 2  2000-01-03     -6
# 3  2000-01-04      8
# 4  2000-01-05     12
# 5  2000-01-06      4
# 6  2000-01-07      5

# %%
f = cml.plot_graph(s, driver='matplotlib')
# Out:
# date date

# %%
type(f)
# Out:
# climetlab.plotting.Plot

# %%
f.driver.figure

# %%
f.driver.figure.add_subplot(2,2,1)
# Out:
# <AxesSubplot:>

# %%
f.driver.figure

# %%
f
