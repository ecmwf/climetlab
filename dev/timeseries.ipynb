# %%
import seaborn as sns
import climetlab as cml

# %%
s = cml.load_source("file", "timeseries.csv")

# %%
f = s.to_pandas()
f
# Out:
#          date  value  value2
# 0  2000-01-01      1      43
# 1  2000-01-02      9      56
# 2  2000-01-03      3      -6
# 3  2000-01-04      1       8
# 4  2000-01-05      5      12
# 5  2000-01-06      2       4
# 6  2000-01-07      7       5

# %%
f = cml.plot_graph(s)
# Out:
# options: Options({})
# date date

# %%
f = cml.plot_graph(s, pandas_dataframe_plot_kwargs=dict(kind='bar'))
# Out:
# options: Options({'pandas_dataframe_plot_kwargs': {'kind': 'bar'}})
# date date

# %%
s.to_pandas().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
f = cml.plot_graph(s, more=1)
# Out:
# options: Options({'more': 1})
# date date

# %%
f.backend.figure.add_subplot(2,2,1)
f.backend.figure
